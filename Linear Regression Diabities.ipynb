# %%
#importing the libraries
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
#Importing dataset
diabetes = datasets.load_diabetes()
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
#Converting the dataset to pandas dataframe
diabetes_dataframe=pd.DataFrame(np.c_[diabetes['data'], diabetes['target']],
                  columns= np.append(diabetes['feature_names'], ['target']))

diabetes_dataframe.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
#Taking the training data from csv file
train_data=np.genfromtxt("C:\\Users\\Abhishek Kumar Singh\\Linear Regression-Diabetes\\0000000000002329_training_diabetes_x_y_train.csv",delimiter=",")
#coverting that to dataframe to increse readibilty
train_data_dataframe=pd.read_csv("C:\\Users\\Abhishek Kumar Singh\\Linear Regression-Diabetes\\0000000000002329_training_diabetes_x_y_train.csv",delimiter=",")

print(train_data_dataframe.shape)
train_data_dataframe.head()
# Out:
# (331, 11)
#       # age       sex       bmi        bp        s1        s2        s3  \
# 0 -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1 -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2  0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3  0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
#
#          s4        s5        s6      Y
# 0  0.034309  0.028017  0.011349  346.0
# 1 -0.002592 -0.012908 -0.054925  104.0
# 2 -0.039493 -0.022512  0.007207   49.0
# 3  0.071210  0.032433  0.048628  180.0
# 4 -0.002592 -0.014956  0.011349  110.0

# %%
#Getting the x_train and y_train
x_train=train_data[:,:-1]
y_train=train_data[:,-1]

# %%
#importing the Linear Regression model
from sklearn.linear_model import LinearRegression
alg=LinearRegression()
alg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Training the data
alg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Taking the testing data from csv file
test_data=np.genfromtxt("C:\\Users\\Abhishek Kumar Singh\\Linear Regression-Diabetes\\0000000000002329_test_diabetes_x_test.csv",delimiter=",")
#coverting that to dataframe to increse readibilty
test_data_dataframe=pd.read_csv("C:\\Users\\Abhishek Kumar Singh\\Linear Regression-Diabetes\\0000000000002329_test_diabetes_x_test.csv",delimiter=",")

print(test_data_dataframe.shape)
test_data_dataframe.head()
# Out:
# (110, 10)
#    0.02354575262934580082  0.05068011873981870252  -0.03746250427835440266  \
# 0               -0.078165               -0.044642                -0.073030
# 1               -0.030942                0.050680                 0.001339
# 2               -0.005515                0.050680                 0.001339
# 3               -0.020045               -0.044642                -0.084886
# 4               -0.034575               -0.044642                -0.037463
#
#    -0.04698505887976939938  -0.09100589560328480043  -0.07553006287033779687  \
# 0                -0.057314                -0.084126                -0.074277
# 1                -0.005671                 0.064477                 0.049416
# 2                -0.084857                -0.011201                -0.016658
# 3                -0.026328                -0.035968                -0.034194
# 4                -0.060757                 0.020446                 0.043466
#
# ...

# %%
#getting the prediction 
y_predict=alg.predict(test_data)
y_predict
# Out:
# array([105.52974799, 105.8039198 , 178.60857225,  79.3828781 ,
#         52.95868706,  98.87263854, 150.71755448,  34.86515216,
#        113.13535727, 161.50184038, 135.8615611 ,  94.71592222,
#        138.48094422, 141.37441723, 158.76862662, 171.65288616,
#        106.44835654, 103.92659639,  95.38693889, 167.40118092,
#        166.53426278, 101.53464712, 252.45035972, 147.02258547,
#        214.78906632, 161.27557106, 210.61315228,  71.78091585,
#        189.65032431, 206.6134259 , 219.98643455, 168.80192534,
#        116.84846127, 178.74399639,  77.03247418,  59.54633214,
#        111.5673781 , 156.95186739, 154.59591259, 198.94457493,
#        115.53884017, 153.46699024,  84.96179518, 113.70337192,
#        142.14155617, 147.31040378,  82.78072358,  77.89237327,
#        128.99006192, 261.58712282, 213.31187775, 243.98791257,
#        167.68132094, 183.69712124, 166.85926884, 202.11440188,
#        220.39235543, 172.40288024, 176.60897931, 109.04656567,
# ...

# %%
#saving the prediction in csv file
np.savetxt("C:/Users/Abhishek Kumar Singh/Linear Regression-Diabetes/Predictoin.csv",y,delimiter=",")
